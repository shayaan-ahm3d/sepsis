# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import feature_load as loader

warnings.filterwarnings("ignore")
df = loader.loadTrainingData(path_pattern='../training_setA/*.psv', max_files=1000)

df.head()
# Out:
# Loading PSV Files: 100%|██████████| 1000/1000 [00:01<00:00, 503.45it/s]
#      HR  O2Sat   Temp     SBP   MAP    DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0  80.0  100.0  36.50  121.00  58.0  41.00  13.5    NaN         1.0  25.0
# 1  76.0  100.0  36.25  113.25  61.0  41.50  12.0    NaN         1.0  25.0
# 2  80.0  100.0  36.25  132.75  71.5  46.25  12.0    NaN         NaN   NaN
# 3  78.0  100.0  36.10  103.50  58.0  43.00  12.0    NaN        -3.0   NaN
# 4  74.0  100.0  36.00  128.75  69.5  44.50  12.5    NaN        -3.0   NaN
#
#    ...  Potassium  Bilirubin_total  TroponinI   Hct  Hgb   PTT  WBC  \
# 0  ...        3.7              NaN        NaN  27.9  8.8  38.1  9.9
# 1  ...        NaN              NaN        NaN  27.9  8.8   NaN  9.9
# 2  ...        NaN              NaN        NaN   NaN  NaN   NaN  NaN
# 3  ...        4.2              NaN        NaN   NaN  NaN   NaN  NaN
# 4  ...        NaN              NaN        NaN   NaN  NaN   NaN  NaN
#
#    Fibrinogen  Platelets  SepsisLabel
# ...

# %%
df.describe()
# Out:
#                 HR         O2Sat          Temp           SBP           MAP  \
# count  35816.00000  34218.000000  13272.000000  33127.000000  34852.000000
# mean      84.65958     97.302049     36.991522    120.826924     78.573674
# std       16.88020      2.826830      0.811517     21.478547     14.952252
# min       23.00000     39.000000     26.670000     24.000000     20.000000
# 25%       72.00000     96.000000     36.500000    105.000000     68.330000
# 50%       84.00000     98.000000     37.000000    119.000000     77.000000
# 75%       96.00000     99.500000     37.500000    134.500000     87.000000
# max      167.00000    100.000000     41.170000    272.000000    288.000000
#
#                 DBP          Resp  EtCO2   BaseExcess         HCO3  ...  \
# count  20300.000000  34748.000000    0.0  4039.000000  3050.000000  ...
# mean      59.925665     18.820882    NaN    -0.753033    24.044262  ...
# std       12.398944      5.452030    NaN     4.162154     4.316482  ...
# ...

# %%
import feature_extraction as cleaner

cleaned_df = cleaner.cleanData(df)

cleaned_df.head()
# Out:
#      HR  O2Sat   Temp     SBP   MAP    DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0  80.0  100.0  36.50  121.00  58.0  41.00  13.5    1.0         1.0  25.0
# 1  76.0  100.0  36.25  113.25  61.0  41.50  12.0    1.0         1.0  25.0
# 2  80.0  100.0  36.25  132.75  71.5  46.25  12.0    1.0         1.0  25.0
# 3  78.0  100.0  36.10  103.50  58.0  43.00  12.0    1.0        -3.0  25.0
# 4  74.0  100.0  36.00  128.75  69.5  44.50  12.5    1.0        -3.0  25.0
#
#    ...  Potassium  Bilirubin_total  TroponinI   Hct  Hgb   PTT  WBC  \
# 0  ...        3.7              1.0        1.0  27.9  8.8  38.1  9.9
# 1  ...        3.7              1.0        1.0  27.9  8.8  38.1  9.9
# 2  ...        3.7              1.0        1.0  27.9  8.8  38.1  9.9
# 3  ...        4.2              1.0        1.0  27.9  8.8  38.1  9.9
# 4  ...        4.2              1.0        1.0  27.9  8.8  38.1  9.9
#
#    Fibrinogen  Platelets  SepsisLabel
# 0       223.0      160.0            0
# ...

# %%
from sklearn.model_selection import train_test_split

X, y = cleaned_df.drop('SepsisLabel', axis=1), cleaned_df[['SepsisLabel']]

X.dtypes
# Out:
# HR                  float64
# O2Sat               float64
# Temp                float64
# SBP                 float64
# MAP                 float64
# DBP                 float64
# Resp                float64
# EtCO2               float64
# BaseExcess          float64
# HCO3                float64
# FiO2                float64
# pH                  float64
# PaCO2               float64
# SaO2                float64
# AST                 float64
# BUN                 float64
# Alkalinephos        float64
# Calcium             float64
# Chloride            float64
# Creatinine          float64
# Bilirubin_direct    float64
# Glucose             float64
# Lactate             float64
# Magnesium           float64
# Phosphate           float64
# Potassium           float64
# Bilirubin_total     float64
# TroponinI           float64
# Hct                 float64
# Hgb                 float64
# PTT                 float64
# WBC                 float64
# Fibrinogen          float64
# ...

# %%
import xgboost as xgb
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Create regression matrices
dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import xgboost as xgb
#       2 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#       4 # Create regression matrices
#
# ModuleNotFoundError: No module named 'xgboost'
